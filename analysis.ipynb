# %% [markdown]
# # Analyze Testcase Runtime

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
data_path = './buffer_stats.csv'
df = pd.read_csv(data_path)
df[['duration_ms', 'locking', 'queues', 'eviction', 'add_page']].describe().T.drop(labels=['count'], axis=1)
# Out:
#                  mean       std    min    25%    50%    75%     max
# duration_ms  0.201867  0.325946  0.002  0.161  0.211  0.218  79.157
# locking      0.141879  0.277485  0.000  0.101  0.151  0.156  79.036
# queues       0.000144  0.008553  0.000  0.000  0.000  0.000   5.280
# eviction     0.000302  0.022587  0.000  0.000  0.000  0.000  13.282
# add_page     0.061600  0.142273  0.055  0.058  0.058  0.059  62.427

# %%
df['duration_ms'].sum()
# Out:
# 80746.80700000003

# %%
sns.boxplot(data=df, x='fifo_size', y='duration_ms')
# Out:
# <Axes: xlabel='fifo_size', ylabel='duration_ms'>

# %%
sns.boxplot(data=df, x='lru_size', y='duration_ms')
# Out:
# <Axes: xlabel='lru_size', ylabel='duration_ms'>

# %%
# fig = plt.figure(figsize=(10, 8))
# ax = fig.add_subplot(111, projection='3d')

# surface = ax.plot_surface(df['fifo_size'], df['lru_size'], df[['duration_ms']], cmap='viridis', alpha=0.8)
